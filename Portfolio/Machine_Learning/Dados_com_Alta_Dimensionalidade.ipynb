# %% [markdown]
# # **1. Importando Dados**

# %%
import pandas as pd

# %%
resultados_exames = pd.read_csv("exames.csv")
resultados_exames
# Out:
#            id diagnostico  exame_1  exame_2  exame_3  exame_4  exame_5  \
# 0      842302           M    17.99    10.38   122.80   103.78   1001.0
# 1      842517           M    20.57    17.77   132.90   103.78   1326.0
# 2    84300903           M    19.69    21.25   130.00   103.78   1203.0
# 3    84348301           M    11.42    20.38    77.58   103.78    386.1
# 4    84358402           M    20.29    14.34   135.10   103.78   1297.0
# ..        ...         ...      ...      ...      ...      ...      ...
# 564    926424           M    21.56    22.39   142.00   103.78   1479.0
# 565    926682           M    20.13    28.25   131.20   103.78   1261.0
# 566    926954           M    16.60    28.08   108.30   103.78    858.1
# 567    927241           M    20.60    29.33   140.10   103.78   1265.0
# 568     92751           B     7.76    24.54    47.92   103.78    181.0
#
#      exame_6  exame_7  exame_8  ...  exame_24  exame_25  exame_26  exame_27  \
# ...

# %% [markdown]
# # **2. Criando um Modelo de Classificação - Random Forest**

# %%
from sklearn.model_selection import train_test_split
from numpy import random

# %%
SEED = 123143
random.seed(SEED)


valores_exames = resultados_exames.drop(columns=["id", "diagnostico"])
diagnostico = resultados_exames.diagnostico


treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames, diagnostico)

# %%
treino_x.head()
# Out:
#      exame_1  exame_2  exame_3  exame_4  exame_5  exame_6  exame_7  exame_8  \
# 114    8.726    15.83    55.84   103.78    230.9  0.11500  0.08201  0.04132
# 457   13.210    25.25    84.10   103.78    537.9  0.08791  0.05205  0.02772
# 269   10.710    20.39    69.50   103.78    344.9  0.10820  0.12890  0.08448
# 520    9.295    13.90    59.96   103.78    257.8  0.13710  0.12250  0.03332
# 38    14.990    25.20    95.54   103.78    698.8  0.09387  0.05131  0.02398
#
#      exame_9  exame_10  ...  exame_24  exame_25  exame_26  exame_27  exame_28  \
# 114  0.01924    0.1649  ...     64.48     284.4   0.17240   0.23640   0.24560
# 457  0.02068    0.1619  ...     91.29     632.9   0.12890   0.10630   0.13900
# 269  0.02867    0.1668  ...     76.51     410.4   0.13350   0.25500   0.25340
# 520  0.02421    0.2197  ...     67.84     326.6   0.18500   0.20970   0.09996
# 38   0.02899    0.1565  ...     95.54     698.8   0.09387   0.05131   0.02398
#
# ...

# %%
treino_y.head()
# Out:
# 114    B
# 457    B
# 269    B
# 520    B
# 38     M
# Name: diagnostico, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classificador = RandomForestClassifier(n_estimators = 100) # quantas árvores de decisão serão construidas neste modelo

classificador.fit(treino_x, treino_y) # ajuste aos dados de treinando

print(classificador.score(teste_x, teste_y)) #recebe os dados de teste e retorna uma acuracia
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f6cb6e45169b> in <cell line: 3>()
#       1 classificador = RandomForestClassifier(n_estimators = 100) # quantas árvores de decisão serão construidas neste modelo
#       2
# ----> 3 classificador.fit(treino_x, treino_y) # ajuste aos dados de treinando
#       4
#       5 print(classificador.score(teste_x, teste_y)) #recebe os dados de teste e retorna uma acuracia
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     343         if issparse(y):
#     344             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345         X, y = self._validate_data(
#     346             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347         )
#
# ...

# %% [markdown]
# ## **2.1 Trabalhando com Valores Vazios**

# %%
# Retorna um boolean com True no local com valores vazios e False no local com valores
resultados_exames.isnull()

# Obtendo o numero de elementos vazios em cada coluna
resultados_exames.isnull().sum()
# Out:
# id               0
# diagnostico      0
# exame_1          0
# exame_2          0
# exame_3          0
# exame_4          0
# exame_5          0
# exame_6          0
# exame_7          0
# exame_8          0
# exame_9          0
# exame_10         0
# exame_11         0
# exame_12         0
# exame_13         0
# exame_14         0
# exame_15         0
# exame_16         0
# exame_17         0
# exame_18         0
# exame_19         0
# exame_20         0
# exame_21         0
# exame_22         0
# exame_23         0
# exame_24         0
# exame_25         0
# exame_26         0
# exame_27         0
# exame_28         0
# exame_29         0
# exame_30         0
# exame_31         0
# exame_32         0
# exame_33       419
# dtype: int64

# %%
# Note que a maioria dos dados dessa coluna são vazios
419 / resultados_exames.shape[0] # 73% são dados vazios
# Out:
# 0.7363796133567663

# %% [markdown]
# Muitos valores faltantes -> Remover coluna
#
# Poucos valores faltantes -> Prencher esses valores

# %%
valores_exames_v1 = valores_exames.drop(columns="exame_33")

# %%
# Refazendo nossos dados de treino e teste e aplicando o modelo
treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v1, 
                                                        diagnostico, test_size = 0.3)


classificador = RandomForestClassifier(n_estimators = 100)
classificador.fit(treino_x, treino_y)
print("Resultado da classificação %.2f%%" % (classificador.score(teste_x, teste_y)* 100))
# Out:
# Resultado da classificação 94.74%

# %% [markdown]
# # **3. Verificando se Nosso Modelo é Bom**

# %%
from sklearn.dummy import DummyClassifier

SEED = 123143
random.seed(SEED)

classificador_bobo = DummyClassifier(strategy = "most_frequent")
classificador_bobo.fit(treino_x, treino_y)
print("Resultado da classificação boba %.2f%%" % (classificador_bobo.score(teste_x, teste_y)* 100))
# Out:
# Resultado da classificação boba 66.08%

# %% [markdown]
# Assim, sabemos que um classificador inocente, que sempre "chuta" o mesmo valor, não chega nem perto da acurácia que conseguimos com o Random Forest, legitimando-o como um bom classificador.

# %% [markdown]
# # **4. Comportamento das Classes**

# %%
# B -> exame_1 == valores
# M -> exame_1 == valores

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dados_plot = pd.concat([diagnostico, valores_exames_v1.iloc[:,0:10]], axis = 1) # juntar dataframe diagnostico com valores_exames_v1
dados_plot = pd.melt(dados_plot, id_vars="diagnostico", var_name="exames", value_name="valores")

plt.figure(figsize=(10,10))
plt.xticks(rotation = 90)
sns.violinplot(x = "exames", y = "valores", hue = "diagnostico", data = dados_plot)
# Out:
# <Axes: xlabel='exames', ylabel='valores'>

# %% [markdown]
# Outro fator que atrapalha a nossa visualização é que temos valores de 0 a 2500. Precisamos estabelecer algum tipo de limite ou padrão que nos permita trabalhar com esses dados de maneira mais eficiente

# %% [markdown]
# ## **4.1 Melhorando a Visualização - Padronizando os Dados**

# %%
from sklearn.preprocessing import StandardScaler

# Padronizando nossos exames
padronizador = StandardScaler()
padronizador.fit(valores_exames_v1)
valores_exames_v2 = padronizador.transform(valores_exames_v1)
valores_exames_v2 = pd.DataFrame(data = valores_exames_v2,columns = valores_exames_v1.keys()) # transformação de um array numpy para um dataframe

dados_plot = pd.concat([diagnostico, valores_exames_v2.iloc[:,0:10]], axis = 1) # juntar dataframe diagnostico com valores_exames_v1
dados_plot = pd.melt(dados_plot, id_vars="diagnostico", var_name="exames", value_name="valores")

plt.figure(figsize=(10,10))
plt.xticks(rotation = 90)
sns.violinplot(x = "exames", y = "valores", hue = "diagnostico", data = dados_plot, split = True)
# Out:
# <Axes: xlabel='exames', ylabel='valores'>

# %%
# Analisando melhor nossos dados

# Exame_2 -> Cristas longe uma da outra (Bom exame para identificar tipo de cancer)
# Exame_6 -> Cristas perto uma da outra (Exame ruim para identificar tipo de cancer)
# Exame_4 -> ? (Analisar mais de perto)

# %%
valores_exames_v2.exame_4 # Valores constantes
# Out:
# 0      1.421085e-14
# 1      1.421085e-14
# 2      1.421085e-14
# 3      1.421085e-14
# 4      1.421085e-14
#            ...
# 564    1.421085e-14
# 565    1.421085e-14
# 566    1.421085e-14
# 567    1.421085e-14
# 568    1.421085e-14
# Name: exame_4, Length: 569, dtype: float64

# %% [markdown]
# Não nos ajuda nessa classificação. Sendo assim, eliminar essa variável não impactará no processo de classificação, pois ela só está ocupando um espaço desnecessário.

# %%
def grafico_violino(valores, inicio, fim):
  dados_plot = pd.concat([diagnostico, valores.iloc[:,inicio:fim]], axis = 1)
  dados_plot = pd.melt(dados_plot, id_vars="diagnostico", var_name="exames", value_name="valores")

  plt.figure(figsize=(10,10))
  plt.xticks(rotation = 90)
  sns.violinplot(x = "exames", y = "valores", hue = "diagnostico", data = dados_plot, split = True)

grafico_violino(valores_exames_v2, 10, 21)

# %%
grafico_violino(valores_exames_v2, 21, 32)

# %% [markdown]
# ### **4.2 Removendo as Colunas com Dados Constantes e Analisando como Isto Afeta Nosso Modelo**

# %%
valores_exames_v3 = valores_exames_v2.drop(columns = ["exame_4", "exame_29"])

# %%
def classificar(valores):
  SEED = 1234
  random.seed(SEED)
  treino_x, teste_x, treino_y, teste_y = train_test_split(valores, 
                                                        diagnostico, test_size = 0.3)


  classificador = RandomForestClassifier(n_estimators = 100)
  classificador.fit(treino_x, treino_y)
  print("Resultado da classificação %.2f%%" % (classificador.score(teste_x, teste_y)* 100))

classificar(valores_exames_v3)
# Out:
# Resultado da classificação 92.98%

# %% [markdown]
# ### **4.3 Correlação dos Nossos Dados**

# %%
matriz_correlacao = valores_exames_v3.corr()

plt.figure(figsize = (17, 15))
sns.heatmap(matriz_correlacao, annot = True, fmt = ".1f")
sns.heatmap(matriz_correlacao)
# Out:
# <Axes: >

# %%
matriz_correlacao_v1 = matriz_correlacao[matriz_correlacao > 0.99]
matriz_correlacao_v1
# Out:
#            exame_1  exame_2   exame_3  exame_5  exame_6  exame_7  exame_8  \
# exame_1   1.000000      NaN  0.997855      NaN      NaN      NaN      NaN
# exame_2        NaN      1.0       NaN      NaN      NaN      NaN      NaN
# exame_3   0.997855      NaN  1.000000      NaN      NaN      NaN      NaN
# exame_5        NaN      NaN       NaN      1.0      NaN      NaN      NaN
# exame_6        NaN      NaN       NaN      NaN      1.0      NaN      NaN
# exame_7        NaN      NaN       NaN      NaN      NaN      1.0      NaN
# exame_8        NaN      NaN       NaN      NaN      NaN      NaN      1.0
# exame_9        NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_10       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_11       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_12       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_13       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# ...

# %%
matriz_correlacao_v2 = matriz_correlacao_v1.sum()
matriz_correlacao_v2
# Out:
# exame_1     1.997855
# exame_2     1.000000
# exame_3     1.997855
# exame_5     1.000000
# exame_6     1.000000
# exame_7     1.000000
# exame_8     1.000000
# exame_9     1.000000
# exame_10    1.000000
# exame_11    1.000000
# exame_12    1.000000
# exame_13    1.000000
# exame_14    1.000000
# exame_15    1.000000
# exame_16    1.000000
# exame_17    1.000000
# exame_18    1.000000
# exame_19    1.000000
# exame_20    1.000000
# exame_21    1.000000
# exame_22    1.993708
# exame_23    1.000000
# exame_24    1.993708
# exame_25    1.000000
# exame_26    1.000000
# exame_27    1.000000
# exame_28    1.000000
# exame_30    1.000000
# exame_31    1.000000
# exame_32    1.000000
# dtype: float64

# %%
variaveis_correlacionadas = matriz_correlacao_v2[matriz_correlacao_v2 > 1]
variaveis_correlacionadas # essas variaveis são altamente correlacionadas, ou seja, podemos exclui-las do dataset
# Out:
# exame_1     1.997855
# exame_3     1.997855
# exame_22    1.993708
# exame_24    1.993708
# dtype: float64

# %%
valores_exames_v4 = valores_exames_v3.drop(columns = variaveis_correlacionadas.keys())

# %% [markdown]
# #### **4.3.1 Como isso afeta nosso modelo?**

# %%
classificar(valores_exames_v4)
# Out:
# Resultado da classificação 91.81%

# %% [markdown]
# #### **4.3.2 Voltando um Pouco**

# %% [markdown]
# Excluimos todas as variaveis correlacionadas, porem devemos deixar uma delas

# %%
valores_exames_v5 = valores_exames_v3.drop(columns=["exame_3", "exame_24"])
classificar(valores_exames_v5)
# Out:
# Resultado da classificação 92.98%

# %% [markdown]
# # **5. Selecionando as k Melhores Features**

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# Gera uma pontuação para cada feature, assim podemos analisar qual é a melhor para nosso processo de classificacao
selecionar_kmelhores = SelectKBest(chi2, k=5)
selecionar_kmelhores
# Out:
# SelectKBest(k=5, score_func=<function chi2 at 0x7fedab04dbd0>)

# %% [markdown]
# ## **5.1 Treinando Nosso Modelo**

# %%
treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v5, diagnostico, test_size = 0.3)
selecionar_kmelhores.fit(treino_x, treino_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-afca6af44475> in <cell line: 2>()
#       1 treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v5, diagnostico, test_size = 0.3)
# ----> 2 selecionar_kmelhores.fit(treino_x, treino_y)
#       3
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     470
#     471         self._check_params(X, y)
# --> 472         score_func_ret = self.score_func(X, y)
#     473         if isinstance(score_func_ret, (list, tuple)):
#     474             self.scores_, self.pvalues_ = score_func_ret
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py in chi2(X, y)
#     215     X = check_array(X, accept_sparse="csr", dtype=(np.float64, np.float32))
# ...

# %%
valores_exames_v5 # temos valores negativos, logo precisamos voltar para os valores antes de padronizar
# Out:
#       exame_1   exame_2   exame_5   exame_6   exame_7   exame_8   exame_9  \
# 0    1.097064 -2.073335  0.984375  1.568466  3.283515  2.652874  2.532475
# 1    1.829821 -0.353632  1.908708 -0.826962 -0.487072 -0.023846  0.548144
# 2    1.579888  0.456187  1.558884  0.942210  1.052926  1.363478  2.037231
# 3   -0.768909  0.253732 -0.764464  3.283553  3.402909  1.915897  1.451707
# 4    1.750297 -1.151816  1.826229  0.280372  0.539340  1.371011  1.428493
# ..        ...       ...       ...       ...       ...       ...       ...
# 564  2.110995  0.721473  2.343856  1.041842  0.219060  1.947285  2.320965
# 565  1.704854  2.085134  1.723842  0.102458 -0.017833  0.693043  1.263669
# 566  0.702284  2.045574  0.577953 -0.840484 -0.038680  0.046588  0.105777
# 567  1.838341  2.336457  1.735218  1.525767  3.272144  3.296944  2.658866
# 568 -1.808401  1.221792 -1.347789 -3.112085 -1.150752 -1.114873 -1.261820
#
#      exame_10  exame_11  exame_12  ...  exame_21  exame_22  exame_23  \
# ...

# %%
valores_exames_v1 # valores não padronizados
# Out:
#      exame_1  exame_2  exame_3  exame_4  exame_5  exame_6  exame_7  exame_8  \
# 0      17.99    10.38   122.80   103.78   1001.0  0.11840  0.27760  0.30010
# 1      20.57    17.77   132.90   103.78   1326.0  0.08474  0.07864  0.08690
# 2      19.69    21.25   130.00   103.78   1203.0  0.10960  0.15990  0.19740
# 3      11.42    20.38    77.58   103.78    386.1  0.14250  0.28390  0.24140
# 4      20.29    14.34   135.10   103.78   1297.0  0.10030  0.13280  0.19800
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 564    21.56    22.39   142.00   103.78   1479.0  0.11100  0.11590  0.24390
# 565    20.13    28.25   131.20   103.78   1261.0  0.09780  0.10340  0.14400
# 566    16.60    28.08   108.30   103.78    858.1  0.08455  0.10230  0.09251
# 567    20.60    29.33   140.10   103.78   1265.0  0.11780  0.27700  0.35140
# 568     7.76    24.54    47.92   103.78    181.0  0.05263  0.04362  0.00000
#
# ...

# %%
# Realizando os tratamentos feitos anteriormente nos dados padronizados
valores_exames_v6 = valores_exames_v1.drop(columns=["exame_4", "exame_29", "exame_3", "exame_24"])

# %%
# Treinando o modelo
SEED = 1234
random.seed(SEED)

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v6, diagnostico, test_size = 0.3)
selecionar_kmelhores.fit(treino_x, treino_y)

treino_kbest = selecionar_kmelhores.transform(treino_x)
teste_kbest = selecionar_kmelhores.transform(teste_x)

# %%
classificador = RandomForestClassifier(n_estimators = 100, random_state=1234)
classificador.fit(treino_kbest, treino_y)

print("Resultado da classificação %.2f%%" % (classificador.score(teste_kbest, teste_y)* 100))
# Out:
# Resultado da classificação 92.40%

# %% [markdown]
# # **6. Matriz de Confusão**

# %%
from sklearn.metrics import confusion_matrix

matriz_confusao = confusion_matrix(teste_y, classificador.predict(teste_kbest))
matriz_confusao
# Out:
# array([[100,   5],
#        [  8,  58]])

# %%
plt.figure(figsize = (10, 8))
sns.set(font_scale = 2)
sns.heatmap(matriz_confusao, annot = True, fmt = "d").set(xlabel = "Predição", ylabel = "Real")
# Out:
# [Text(0.5, 40.249999999999986, 'Predição'), Text(77.25, 0.5, 'Real')]

# %% [markdown]
# # **7. Recursive Feature Elimination**

# %% [markdown]
# Nessa nova técnica, por meio da acurácia, que será nossa forma de avaliação, nosso classificador saberá qual das features é mais importante pra ele, descartando as de menor acurácia. Esse processo será feito sucessivamente até atingir o número de features selecionado

# %%
from sklearn.feature_selection import RFE

#teste
treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v6, diagnostico, test_size = 0.3)
classificador = RandomForestClassifier(n_estimators=100, random_state = 1234)
classificador.fit(treino_x, treino_y)

#modelo
selecionador_rfe = RFE(estimator = classificador, n_features_to_select = 5, step = 1)
selecionador_rfe.fit(treino_x, treino_y)
treino_rfe = selecionador_rfe.transform(treino_x)
teste_rfe = selecionador_rfe.transform(teste_x)
classificador.fit(treino_rfe, treino_y)

matriz_confusao = confusion_matrix(teste_y, classificador.predict(teste_rfe))
plt.figure(figsize = (10, 8))
sns.set(font_scale = 2)
sns.heatmap(matriz_confusao, annot = True, fmt = "d").set(xlabel = "Predição", ylabel = "Real")

print("Resultado da classificação %.2f%%" % (classificador.score(teste_rfe, teste_y)* 100))
# Out:
# Resultado da classificação 91.81%

# %% [markdown]
# # **8. RFECV - Diz Qual Conjunto de Features que Gerará o Melhor Resultado**

# %%
from sklearn.feature_selection import RFECV

SEED = 1234
random.seed(SEED)

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v6,
                                                       diagnostico,
                                                       test_size = 0.3)

classificador = RandomForestClassifier(n_estimators=100, random_state = 1234)
classificador.fit(treino_x, treino_y)


selecionador_rfecv = RFECV(estimator = classificador, cv = 5, scoring = "accuracy", step = 1)
selecionador_rfecv.fit(treino_x, treino_y)
treino_rfecv = selecionador_rfecv.transform(treino_x)
teste_rfecv = selecionador_rfecv.transform(teste_x)
classificador.fit(treino_rfecv, treino_y)

matriz_confusao = confusion_matrix(teste_y, classificador.predict(teste_rfecv))
plt.figure(figsize = (10, 8))
sns.set(font_scale = 2)
sns.heatmap(matriz_confusao, annot = True, fmt = "d").set(xlabel = "Predição", ylabel = "Real")

print("Resultado da classificação %.2f%%" % (classificador.score(teste_rfecv, teste_y)* 100))
# Out:
# Resultado da classificação 92.98%

# %%
# Acessando os numeros das features selecionadas
selecionador_rfecv.n_features_
# Out:
# 26

# %%
treino_x.columns[selecionador_rfecv.support_]
# Out:
# Index(['exame_1', 'exame_2', 'exame_5', 'exame_6', 'exame_7', 'exame_8',
#        'exame_9', 'exame_10', 'exame_12', 'exame_13', 'exame_14', 'exame_15',
#        'exame_16', 'exame_18', 'exame_19', 'exame_20', 'exame_21', 'exame_22',
#        'exame_23', 'exame_25', 'exame_26', 'exame_27', 'exame_28', 'exame_30',
#        'exame_31', 'exame_32'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
plt.xlabel("Número de exames")
plt.ylabel("Acurácia")

plt.plot(range(1, len(selecionador_rfecv.grid_scores_) + 1), selecionador_rfecv.grid_scores_)
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-2fbe99a79a5c> in <cell line: 7>()
#       5 plt.ylabel("Acurácia")
#       6
# ----> 7 plt.plot(range(1, len(selecionador_rfecv.grid_scores_) + 1), selecionador_rfecv.grid_scores)
#       8 plt.show
#
# AttributeError: 'RFECV' object has no attribute 'grid_scores_'

# %%
selecionador_rfecv.grid_scores_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-e673d1ae45bd> in <cell line: 1>()
# ----> 1 selecionador_rfecv.grid_scores_
#
# AttributeError: 'RFECV' object has no attribute 'grid_scores_'

# %% [markdown]
# # **9. Visualizando dados no Plano**

# %%
from sklearn.feature_selection import RFE

SEED = 1234
random.seed(SEED)

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v6,
                                                       diagnostico,
                                                       test_size = 0.3)

classificador = RandomForestClassifier(n_estimators=100, random_state = 1234)
classificador.fit(treino_x, treino_y)


selecionador_rfe = RFE(estimator = classificador, n_features_to_select = 2, step = 1)
selecionador_rfe.fit(treino_x, treino_y)
treino_rfe = selecionador_rfe.transform(treino_x)
teste_rfe = selecionador_rfe.transform(teste_x)
classificador.fit(treino_rfe, treino_y)

matriz_confusao = confusion_matrix(teste_y, classificador.predict(teste_rfe))
plt.figure(figsize = (10, 8))
sns.set(font_scale = 2)
sns.heatmap(matriz_confusao, annot = True, fmt = "d").set(xlabel = "Predição", ylabel = "Real")

print("Resultado da classificação %.2f%%" % (classificador.score(teste_rfe, teste_y)* 100))
# Out:
# Resultado da classificação 87.13%

# %%
valores_exames_v7 = selecionador_rfe.transform(valores_exames_v6)
valores_exames_v7.shape
# Out:
# (569, 2)

# %%
import seaborn as sns 

plt.figure(figsize=(14, 8))
sns.scatterplot(x = valores_exames_v7[:,0], y = valores_exames_v7[:,1], hue = diagnostico)
# Out:
# <Axes: >

# %% [markdown]
# Porém, tendo excluído dimensões até restarem apenas duas, não estamos perdendo muita informação? Na verdade sim. Sendo assim, no caso de visualizações desse tipo, selecionar apenas duas features não é o mais adequado. Precisaremos encontrar uma maneira de preservar as características que irão diferenciar os tipos de câncer

# %% [markdown]
# ## **9.1 - PCA e TSNE**

# %% [markdown]
# O PCA opera uma transformação matemática sobre os dados, na qual as primeiras dimensões serão as variáveis que manterão o maior volume possível de informação.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
valores_exames_v8 = pca.fit_transform(valores_exames_v6)

plt.figure(figsize=(14, 8))
sns.scatterplot(x = valores_exames_v8[:,0], y = valores_exames_v8[:,1], hue = diagnostico)
# Out:
# <Axes: >

# %% [markdown]
# PCA se comporta melhor com os dados já normalizados

# %%
pca = PCA(n_components = 2)
valores_exames_v8 = pca.fit_transform(valores_exames_v5)

plt.figure(figsize=(14, 8))
sns.scatterplot(x = valores_exames_v8[:,0], y = valores_exames_v8[:,1], hue = diagnostico)
# Out:
# <Axes: >

# %% [markdown]
# t-SNE tenta manter as distâncias entre os pontos

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components = 2)
valores_exames_v9 = tsne.fit_transform(valores_exames_v5)

plt.figure(figsize=(14, 8))
sns.scatterplot(x = valores_exames_v9[:,0], y = valores_exames_v9[:,1], hue = diagnostico)
# Out:
# <Axes: >
